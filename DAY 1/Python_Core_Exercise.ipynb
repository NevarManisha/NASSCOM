# %% [markdown]
# <a href="https://colab.research.google.com/github/NevarManisha/NASSCOM/blob/main/DAY%201/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime,random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

print("\n--- Task 1: Data Generation and Basic Structures ---")

# =====================================================
# Task 1.1
# =====================================================
raw_sensor_data = []

base_time = datetime.datetime.now()

for i in range(100):
    timestamp = (base_time + datetime.timedelta(minutes=i)).strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03d}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    low, high = READING_RANGES[device_type]
    value = round(random.uniform(low, high), 2)

    raw_sensor_data.append(
        (timestamp, device_id, device_type, location, value)
    )

print("Generated", len(raw_sensor_data), "sensor readings.")

# =====================================================
# Task 1.2
# =====================================================
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        })

print("Temperature readings:", len(temperature_readings))

# =====================================================
# Task 1.3
# =====================================================
unique_locations = {reading[3] for reading in raw_sensor_data}

print("Unique locations:", unique_locations)

# =====================================================
# Task 1.4
# =====================================================
device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

for reading in raw_sensor_data:
    device = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device]

    current_min = min(current_min, value)
    current_max = max(current_max, value)

    device_stats[device] = (current_min, current_max)

print("Device Statistics")
for k, v in device_stats.items():
    print(k, ":", v)

# =====================================================
# Task 1.5
# =====================================================

print("\n--- Task 1.5: Advanced Indexing and Slicing ---")

sample_string = "PythonProgrammingIsFun"

# 1.5.1
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]

# 1.5.2
substring_1 = sample_string[6:17]
substring_2 = sample_string[5::-1]

# 1.5.3
fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

print("Substring 1:", substring_1)
print("Substring 2:", substring_2)
print("Suffix:", device_type_suffix)

# =====================================================
# Task 2
# =====================================================

print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1
def get_readings_by_location(readings_list, target_location):
    return [reading for reading in readings_list if reading[3] == target_location]


# 2.2
def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = sum(item["temperature_celsius"] for item in temp_data_list)
    return total / len(temp_data_list)


# 2.3
def generate_report_line(reading_dict):
    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )

print("Average Temperature:",
      round(calculate_average_temperature(temperature_readings), 2))

# =====================================================
# Task 3
# =====================================================

print("\n--- Task 3: Core Library Usage ---")

# 3.1
reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print("Directory created.")
else:
    print("Directory already exists.")

# 3.2

if len(raw_sensor_data) > 1:

    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    fmt = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.datetime.strptime(first_timestamp_str, fmt)
    last_dt = datetime.datetime.strptime(last_timestamp_str, fmt)

    duration = last_dt - first_dt

    days = duration.days

    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"Duration: {days} days {hours} hours {minutes} minutes")

# 3.3

random_values = [random.randint(100, 200) for _ in range(5)]

print("Random Values:", random_values)

# =====================================================
# Task 4
# =====================================================

print("\n--- Task 4: File Handling ---")

# 4.1

report_filename = os.path.join(
    reports_dir,
    "temperature_report.txt"
)

try:

    with open(report_filename, "w") as f:

        for reading in temperature_readings:
            f.write(generate_report_line(reading) + "\n")

    print("Temperature report saved.")

except IOError as e:

    print("File write error:", e)

# 4.2

read_report_lines = []

try:

    with open(report_filename, "r") as f:
        read_report_lines = f.readlines()

    print("\nFirst 3 lines of report:")

    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:

    print("File read error:", e)

# =====================================================
# Demonstration
# =====================================================

print("\n--- Demonstration ---")

lab1 = get_readings_by_location(raw_sensor_data, "Lab1")

print("Lab1 readings:", len(lab1))

print("Average Temperature:",
      round(calculate_average_temperature(temperature_readings), 2))

print("\nDevice Statistics")
for device, stats in device_stats.items():
    print(device, stats)

print("\nUnique Locations")
print(unique_locations)

print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime,random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# Generated 100 sensor readings.
# Temperature readings: 22
# Unique locations: {'OfficeA', 'Lab1', 'OfficeB', 'Lab2', 'Warehouse'}
# Device Statistics
# Temperature_Sensor : (18.78, 29.77)
# Humidity_Sensor : (30.61, 79.66)
# Pressure_Sensor : (982.8, 1028.31)
# Light_Sensor : (106.49, 901.49)
#
# --- Task 1.5: Advanced Indexing and Slicing ---
# Substring 1: Programming
# Substring 2: nohtyP
# Suffix: Sensor
#
# --- Task 2: Function Definitions and Usage ---
# Average Temperature: 24.49
#
# --- Task 3: Core Library Usage ---
# Directory created.
# Duration: 0 days 1 hours 39 minutes
# Random Values: [112, 153, 171, 191, 148]
#
# --- Task 4: File Handling ---
# Temperature report saved.
#
# First 3 lines of report:
# [2026-07-24 16:04:22] Device DEV006 at Warehouse: 26.56°C
# [2026-07-24 16:14:22] Device DEV016 at OfficeB: 28.16°C
# [2026-07-24 16:17:22] Device DEV019 at OfficeA: 27.93°C
#
# --- Demonstration ---
# Lab1 readings: 20
# Average Temperature: 24.49
#
# Device Statistics
# Temperature_Sensor (18.78, 29.77)
# Humidity_Sensor (30.61, 79.66)
# Pressure_Sensor (982.8, 1028.31)
# Light_Sensor (106.49, 901.49)
#
# Unique Locations
# {'OfficeA', 'Lab1', 'OfficeB', 'Lab2', 'Warehouse'}
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
